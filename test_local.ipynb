# %%
#!pip install colab-xterm
#%load_ext colabxterm
#%xterm

# %% [markdown]
# Issues:
# * No terminal access unless I go for the prop version

# %% [markdown]
# ### Instructions for connecting to local session
#
# * Open anaconda prompt
#   * conda env list
#   * conda activate env_name
#
# * Check the follwing is installed:
#
# pip install jupyter_http_over_ws
# jupyter serverextension enable --py jupyter_http_over_ws
#
# * Run this command in the notebook:
#
# jupyter notebook --NotebookApp.allow_origin='https://colab.research.google.com' --port=8890 --NotebookApp.port_retries=0
#   * OR
# python -m notebook --NotebookApp.allow_origin='https://colab.research.google.com' --port=8890 --NotebookApp.port_retries=0
#
# * Copy the FULL link that starts with local host.
#
# * Paste into local connection box
#
# * Pip installing appears to add to the venv in conda

# %%
# !git clone https://github.com/aworma4/AIG.git
# Out:
# Cloning into 'AIG'...

# %%
#break out of interpreter using %cd 
# %cd AIG
# Out:
# C:\Users\AT030915\AIG

# %% [markdown]
# https://hershkoy.medium.com/how-to-use-colab-with-git-on-your-local-machine-1c95586967e
